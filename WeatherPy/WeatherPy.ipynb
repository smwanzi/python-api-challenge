# %% [markdown]
# # WeatherPy
#
# ## Summary Observations
#
# o	Temperature drops as you move away from the equator
# o	There is no correlation between latitude and humidity.
# o	There is no correlation between latitude and cloudiness
# o	There is no correlation between latitude and wind speed.
# o	In the Northern Hemisphere, as you move away from the equator the temperature decreases.
# o	In the Southern Hemisphere, as you get closer to the equator the temperature increases

# %% [markdown]
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import date
from pprint import pprint

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + api_key
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + api_key

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# #Initiate counter for city number below
# number = 1

# #Lists for holding required items
# city_name = []
# country = []
# date =[]
# lat = []
# lng = []
# temp = []
# humid = []
# clouds = []
# wind = []

# #Loop through each city, extract required items, and print result
# print('------------------------------')
# print('Start of Records')
# print('------------------------------')

# for city in cities:
#     try:
#         city_data = (requests.get(url + '&q=' + city)).json()
#         city_name.append(city_data['name'])
#         country.append(city_data["sys"]['country'])#added for country
#         lat.append(city_data['coord']['lat'])
#         lng.append(city_data['coord']['lon'])
#         temp.append(city_data['main']['temp'])
#         humid.append(city_data['main']['humidity'])
#         clouds.append(city_data['clouds']['all'])
#         wind.append(city_data['wind']['speed'])
#         print(f'City number {number} of {len(cities)} complete. | Added {city}')
#         number = number + 1
    
#     except KeyError:
#         print(f'Missing data in city number {number} of {len(cities)}. | Skipping {city}')
#         number = number + 1
        
# print('------------------------------')
# print('End of Records')
# print('------------------------------')
# Out:
# ------------------------------
# Start of Records
# ------------------------------
# City number 1 of 638 complete. | Added tasiilaq
# City number 2 of 638 complete. | Added ushuaia
# City number 3 of 638 complete. | Added vardo
# City number 4 of 638 complete. | Added pevek
# City number 5 of 638 complete. | Added coquimbo
# City number 6 of 638 complete. | Added pizarro
# City number 7 of 638 complete. | Added jamestown
# City number 8 of 638 complete. | Added pitimbu
# City number 9 of 638 complete. | Added nsoko
# City number 10 of 638 complete. | Added nikolskoye
# City number 11 of 638 complete. | Added rikitea
# City number 12 of 638 complete. | Added lorengau
# City number 13 of 638 complete. | Added dikson
# City number 14 of 638 complete. | Added pochutla
# City number 15 of 638 complete. | Added mahebourg
# City number 16 of 638 complete. | Added cabo san lucas
# City number 17 of 638 complete. | Added punta arenas
# City number 18 of 638 complete. | Added jiuquan
# ...

# %%
#Save a CSV of all retrieved data and a PNG image for each scatter plot.
#Create a dataframe with required items
city_data_df = pd.DataFrame({'City': city_name,
                            'Country': country,
                            'Latitude': lat,
                            'Longitude': lng,
                            'Temperature': temp,
                            'Humidity': humid,
                            'Cloudiness': clouds,
                            'Wind Speed': wind})

#Save dataframe as csv
#pd.DataFrame.to_csv(city_data_df, 'city_data.csv')


pd.DataFrame.to_csv(city_data_df,"Resources/Cities by Coordinates.csv", encoding="utf-8", index=False) 
city_data_df.head()
# Out:
#        City Country  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0  Tasiilaq      GL     65.61     -37.64        24.80        68         100
# 1   Ushuaia      AR    -54.80     -68.30        39.20        64          40
# 2     Vardø      NO     70.37      31.11        28.11        93          74
# 3     Pevek      RU     69.70     170.31         9.97        91           4
# 4  Coquimbo      CL    -29.95     -71.34        57.20        87          74
#
#    Wind Speed
# 0       14.99
# 1        9.17
# 2       13.85
# 3       14.23
# 4        5.82

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Plot latitude vs temperature and save as .png

# Increase the size of the figure
plt.figure(figsize=(9,5))
plt.scatter(city_data_df['Latitude'], city_data_df['Temperature'],edgecolor="black", linewidths=1, 
            marker="o", color='b', alpha=0.8)
plt.title(f'City Latitude vs. Temperature {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid(True)
plt.savefig('lat_temp.png', bbox_inches='tight')

# %% [markdown]
# The plot shows that temperature drops as you move away from the equator.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Plot latitude vs humidity and save as .png
# Increase the size of the figure
plt.figure(figsize=(10,5))
plt.scatter(city_data_df['Latitude'], city_data_df['Humidity'],edgecolor="black", linewidths=1, 
            marker="o", color='orange', alpha=0.8)
plt.title(f'City Latitude vs. Humidity {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
plt.savefig('lat_humid.png', bbox_inches='tight')

# %% [markdown]
# The plot shows there is no definite relationship between latitude and humidity

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Plot latitude vs cloudiness and save as .png
# Increase the size of the figure
plt.figure(figsize=(9,5))
plt.scatter(city_data_df['Latitude'], city_data_df['Cloudiness'], linewidths=1, 
            marker="o",color='green', alpha=0.8)
plt.title(f'City Latitude vs. Cloudiness {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
plt.savefig('lat_cloud.png', bbox_inches='tight')

# %% [markdown]
# The plot shows there is no definite relationship between latitude and humidity

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Plot latitude vs Wind Speed and save as .png
# Increase the size of the figure
plt.figure(figsize=(9,5))
plt.scatter(city_data_df['Latitude'], city_data_df['Wind Speed'],linewidths=1, 
            marker="o", color='yellow', alpha=0.9)
plt.title(f'City Latitude vs. Wind Speed {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.savefig('lat_wind.png', bbox_inches='tight')

# %% [markdown]
# The plot shows there is no definite relationship between latitude and humidity

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# Define plotting function
from scipy.stats import linregress

def plotLinearRegression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
    print(f"The r-squared is: {rvalue}")
    regress_values = xdata * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.figure(figsize=(9,5))
    plt.scatter(xdata,ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,lblpos,fontsize=15,color="red")
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    plt.savefig(f"Figures/fig{ifig}.png")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = city_data_df.loc[pd.to_numeric(city_data_df["Latitude"]).astype(float) > 0, :]
southern_df = city_data_df.loc[pd.to_numeric(city_data_df["Latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression
xlbl = "Latitude"
ylbl = "Temperature"
lblpos = (0,25)
plotLinearRegression(northern_df[xlbl],northern_df[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: -0.8960592083016384

# %% [markdown]
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression

xlbl = "Latitude"
ylbl = "Temperature"
lblpos = (-55,90)
plotLinearRegression(southern_df[xlbl],southern_df[ylbl],xlbl,ylbl,lblpos,6)
# Out:
# The r-squared is: 0.6261768947548229

# %% [markdown]
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
xlbl = "Latitude"
ylbl = "Humidity"
lblpos = (45,10)
plotLinearRegression(northern_df[xlbl],northern_df[ylbl],xlbl,ylbl,lblpos,7)
# Out:
# The r-squared is: 0.258913177748811

# %% [markdown]
# The regression does not show a correlation between latitude and humidity.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
xlbl = "Latitude"
ylbl = "Humidity"
lblpos = (-55,15)
plotLinearRegression(southern_df[xlbl],southern_df[ylbl],xlbl,ylbl,lblpos,8)
# Out:
# The r-squared is: 0.24002716153702233

# %% [markdown]
# The regression does not show a correlation between latitude and humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
xlbl = "Latitude"
ylbl = "Cloudiness"
lblpos = (20,40)
plotLinearRegression(northern_df[xlbl],northern_df[ylbl],xlbl,ylbl,lblpos,9)
# Out:
# The r-squared is: 0.14866917402387014

# %% [markdown]
# The regression does not show a correlation between latitude and cloudiness.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Sourhern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
xlbl = "Latitude"
ylbl = "Cloudiness"
lblpos = (-55,50)
plotLinearRegression(southern_df[xlbl],southern_df[ylbl],xlbl,ylbl,lblpos,10)
# Out:
# The r-squared is: 0.19697271014296525

# %% [markdown]
# The regression does not show a correlation between latitude and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

xlbl = "Latitude"
ylbl = "Wind Speed"
lblpos = (0,30)
plotLinearRegression(northern_df[xlbl],northern_df[ylbl],xlbl,ylbl,lblpos,11)
# Out:
# The r-squared is: 0.14241225421547088

# %% [markdown]
# The regression does not show a correlation between latitude and wind speed.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
xlbl = "Latitude"
ylbl = "Wind Speed"
lblpos = (-25,33)
plotLinearRegression(southern_df[xlbl],southern_df[ylbl],xlbl,ylbl,lblpos,12)
# Out:
# The r-squared is: -0.2913155898891198

# %% [markdown]
# The regression does not show a correlation between latitude and wind speed.
